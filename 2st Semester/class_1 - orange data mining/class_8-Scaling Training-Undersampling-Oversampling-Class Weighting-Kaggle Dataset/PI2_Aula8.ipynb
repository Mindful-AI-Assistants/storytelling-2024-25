# %%
# !kaggle datasets download -d mlg-ulb/creditcardfraud
# Out:
# Dataset URL: https://www.kaggle.com/datasets/mlg-ulb/creditcardfraud
# License(s): DbCL-1.0
# Downloading creditcardfraud.zip to /content
#  96% 63.0M/66.0M [00:00<00:00, 135MB/s]
# 100% 66.0M/66.0M [00:00<00:00, 121MB/s]

# %%
# !unzip creditcardfraud.zip
# Out:
# Archive:  creditcardfraud.zip
#   inflating: creditcard.csv

# %%
#from google.colab import files
#files.download('/content/creditcard.csv')

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
df = pd.read_csv('/content/creditcard.csv')
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 31 columns]

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
X = df.drop('Class', axis=1)
y = df['Class']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# Como persistir o scaler treinado? Você pode usar para dados novos!

# %%
import pickle

pickle.dump(scaler, open('scaler.pkl', 'wb'))

# %% [markdown]
# Como carregar depois?

# %%
#pickle.load(open('scaler.pkl', 'rb'))

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
clf = LogisticRegression(max_iter=1000)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9991222218320986

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.86      0.58      0.70        98
#
#     accuracy                           1.00     56962
#    macro avg       0.93      0.79      0.85     56962
# weighted avg       1.00      1.00      1.00     56962

# %%
y_true = y_test
y_pred = y_pred

pd.DataFrame(confusion_matrix(y_true, y_pred))
# Out:
#        0   1
# 0  56855   9
# 1     41  57

# %% [markdown]
# ---

# %% [markdown]
# ## Undersampling

# %%
contagem = df['Class'].value_counts().sort_index()
contagem
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
contagem.argmin(), contagem.min()
# Out:
# (1, 492)

# %%
classes = [0,1] # Especificação das classes
dicionario = {i: df[ df['Class'] == i] for i in classes}

# %%
for key in dicionario:
  dicionario[key] = dicionario[key].sample(contagem.min(), replace=False)

# %%
df2 = pd.concat([dicionario[i] for i in classes], ignore_index=True, sort=False)
df2
# Out:
#          Time         V1         V2         V3        V4         V5        V6  \
# 0     40889.0   1.156377   0.203151   0.604181  0.497702  -0.271862 -0.296557
# 1    125339.0   2.248934  -1.508221  -0.699479 -1.429216  -1.629134 -0.916798
# 2    129573.0   2.178935  -1.791652  -0.265043 -1.736480  -1.625332  0.437380
# 3    168970.0  -0.966377   0.595670   1.195735 -2.340329  -0.171954 -0.526465
# 4     79797.0  -6.488841 -12.674297  -4.379555  4.570485  -2.323229  5.724584
# ..        ...        ...        ...        ...       ...        ...       ...
# 979  146179.0  -0.067672   4.251181  -6.540388  7.283657   0.513541 -2.635066
# 980   65936.0  -3.593476   0.781442  -1.822448  0.605761  -1.194656 -0.517195
# 981  144839.0  -6.423306   1.658515  -5.866440  2.052064  -0.615817 -3.372266
# 982   29753.0   0.269614   3.549755  -5.810353  5.809370   1.538808 -2.269219
# 983   94362.0 -26.457745  16.497472 -30.177317  8.904157 -17.892600 -1.227904
#
#             V7         V8        V9  ...       V21       V22       V23  \
# 0    -0.061994   0.024856 -0.343575  ... -0.155014 -0.421046  0.168148
# 1    -1.238340  -0.159155 -0.912794  ... -0.158460 -0.003512  0.264406
# 2    -1.939119   0.265913 -0.794349  ... -0.105814  0.060763  0.304873
# 3     0.058720   0.434024  0.677843  ... -0.177403 -0.600125 -0.200134
# 4     3.966477   0.131055 -0.685224  ...  2.585183 -1.723802 -3.560551
# ..         ...        ...       ...  ...       ...       ...       ...
# 979  -1.865911   0.780272 -3.868248  ...  0.415437 -0.469938  0.007128
# 980  -1.722523   0.128890  0.014963  ...  0.351792  0.391249 -0.252875
# 981  -5.036556   2.643106 -2.274630  ...  0.641211 -0.256678 -2.337233
# 982  -0.824203   0.351070 -3.759059  ...  0.371121 -0.322290 -0.549856
# 983 -31.197329 -11.438920 -9.462573  ... -8.755698  3.460893  0.896538
#
#           V24       V25       V26       V27       V28   Amount  Class
# 0    0.239078  0.111323  0.091504 -0.011725  0.009435     3.87      0
# 1   -0.065596 -0.313934 -0.172184  0.014063 -0.047275    28.60      0
# 2    0.229450 -0.546686 -0.282322  0.044668 -0.033449    43.06      0
# 3    0.669994  0.386400 -0.383949 -0.056200 -0.012554     4.10      0
# 4    1.208859 -1.045833 -0.297738 -0.701108  0.726608  3974.58      0
# ..        ...       ...       ...       ...       ...      ...    ...
# 979 -0.388147 -0.493398  0.466468  0.566370  0.262990     0.77      1
# 980 -0.498042  0.010172  0.909929 -1.478767  0.722673   101.50      1
# 981 -0.158278  1.198797 -0.261258  0.780125 -0.731801     0.00      1
# 982 -0.520629  1.378210  0.564714  0.553255  0.402400     0.68      1
# 983  0.254836 -0.738097 -0.966564 -7.263482 -1.324884     1.00      1
#
# [984 rows x 31 columns]

# %%
df2['Class'].value_counts()
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %%
X = df2.drop('Class', axis=1)
y = df2['Class']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)
clf = LogisticRegression(max_iter=1000)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95        99
#            1       0.99      0.90      0.94        98
#
#     accuracy                           0.94       197
#    macro avg       0.95      0.94      0.94       197
# weighted avg       0.95      0.94      0.94       197

# %% [markdown]
# ## Oversampling

# %%
contagem.argmax(), contagem.max()
# Out:
# (0, 284315)

# %%
classes = [0,1] # Especificação das classes
dicionario = {i: df[ df['Class'] == i] for i in classes}

# %%
for key in dicionario:
  dicionario[key] = dicionario[key].sample(contagem.max(), replace=True)

# %%
df3 = pd.concat([dicionario[i] for i in classes], ignore_index=True, sort=False)
df3
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 0       156414.0  1.989619  0.630446 -0.771979  3.547975  0.863637  0.493785
# 1       121120.0  2.062289  0.000520 -1.309206  0.360896  0.006960 -1.280808
# 2       144059.0 -0.917372  0.404202  1.721509  0.895681  0.853466  1.063255
# 3        60444.0 -0.932575 -0.111427  2.338879 -1.903852 -0.881497  0.221467
# 4       130117.0 -0.217374  0.905649  1.038758 -0.164872  0.196714 -1.499691
# ...          ...       ...       ...       ...       ...       ...       ...
# 568625  160870.0 -0.644278  5.002352 -8.252739  7.756915 -0.216267 -2.751496
# 568626   62059.0 -1.644403  3.129852 -2.576977  3.415573 -0.448525 -1.241893
# 568627  139951.0 -2.921944 -0.228062 -5.877289  2.201884 -1.935440  0.631141
# 568628   32686.0  0.287953  1.728735 -1.652173  3.813544 -1.090927 -0.984745
# 568629   76867.0  1.082566  1.094862 -1.367020  2.012554  0.708142 -0.807712
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 0       0.150502 -0.103736 -0.971190  ... -0.057667 -0.008399  0.084216
# 1       0.257498 -0.390897  0.569512  ...  0.253830  0.912500  0.003243
# 2       0.405492  0.387165 -0.367480  ... -0.431646 -1.268320 -0.014058
# 3      -0.208679  0.275890 -1.188645  ...  0.513139  1.271202 -0.335017
# 4       1.362926 -0.499026  0.019132  ... -0.173965 -0.123688  0.086016
# ...          ...       ...       ...  ...       ...       ...       ...
# 568625 -3.358857  1.406268 -4.403852  ...  0.587728 -0.605759  0.033746
# 568626 -1.991652  1.002665 -2.809071  ...  0.417762 -0.648576 -0.318617
# 568627 -1.245106  1.511348 -1.899987  ...  1.441622  0.895528  1.385511
# 568628 -2.202318  0.555088 -2.033892  ...  0.262202 -0.633528  0.092891
# 568629  0.151952  0.158353  0.009872  ... -0.325284 -0.734344 -0.106725
#
#              V24       V25       V26       V27       V28  Amount  Class
# 0      -1.062290  0.049001 -0.035909 -0.010141 -0.050917    0.00      0
# 1       0.028833  0.258333 -0.106243 -0.015604 -0.058569    3.11      0
# 2       0.152664  0.411627 -0.823885  0.078954  0.084360   59.99      0
# 3       0.048295  0.315111 -0.130452 -0.047382  0.048377   69.99      0
# 4       0.905240 -0.617961 -0.657864  0.261071  0.040393   17.99      0
# ...          ...       ...       ...       ...       ...     ...    ...
# 568625 -0.756170 -0.008172  0.532772  0.663970  0.192067    0.77      1
# 568626 -0.680413  0.389869  0.055750  0.394682  0.298821    6.62      1
# 568627 -2.028024  0.509131  0.172643  0.726781  0.234514  723.21      1
# 568628  0.187613  0.368708 -0.132474  0.576561  0.309843    0.00      1
# 568629 -0.224999  0.569167 -0.335033  0.089140  0.112337    1.00      1
#
# [568630 rows x 31 columns]

# %%
df3['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1    284315
# Name: count, dtype: int64

# %%
X = df3.drop('Class', axis=1)
y = df3['Class']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)
clf = LogisticRegression(max_iter=1000)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.95     56746
#            1       0.98      0.92      0.95     56980
#
#     accuracy                           0.95    113726
#    macro avg       0.95      0.95      0.95    113726
# weighted avg       0.95      0.95      0.95    113726

# %% [markdown]
# ### Ponderação de classes
#
# $$
# \text{class weight} = 1 - \left( \frac{\text{number of samples of the class} }{ \text{total number of samples} } \right)
# $$

# %%
ntotal = contagem.sum()

# %%
w = {i: 1-contagem[i]/ntotal for i in classes}
w
# Out:
# {0: 0.0017274856306200848, 1: 0.9982725143693799}

# %%
X = df.drop('Class', axis=1)
y = df['Class']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)
clf = LogisticRegression(max_iter=1000, class_weight=w)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     56864
#            1       0.07      0.92      0.13        98
#
#     accuracy                           0.98     56962
#    macro avg       0.53      0.95      0.56     56962
# weighted avg       1.00      0.98      0.99     56962
