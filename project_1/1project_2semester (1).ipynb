# %%
# !unzip automobile.zip
# Out:
# Archive:  automobile.zip
# replace Index? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
# Preparando a base de dados
# importando bibliotecas usadas na análise de dados


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Definir as colunas do dataframe
colunas = [
    'symboling',
    'normalized-losses',
    'make',
    'fuel-type',
    'aspiration',
    'num-of-doors',
    'body-style',
    'drive-wheels',
    'engine-location',
    'wheel-base',
    'length',
    'width',
    'height',
    'curb-weight',
    'engine-type',
    'num-of-cylinders',
    'engine-size',
    'fuel-system',
    'bore',
    'stroke',
    'compression-ratio',
    'horsepower',
    'peak-rpm',
    'city-mpg',
    'highway-mpg',
    'price'
]

# %%
with open(r"/content/drive/MyDrive/Aula 2/colunas", "r") as columns: # Lendo o arquivo e salvando em columns

  ''' Lendo o arquivo e usando o comando splitlines que separa o texto em linhas,
consequentemente retornando uma lista com os nomes das colunas'''
  columns = columns.read().splitlines()
columns
# Out:
# ['symboling',
#  'normalized-losses',
#  'make',
#  'fuel-type',
#  'aspiration',
#  'num-of-doors',
#  'body-style',
#  'drive-wheels',
#  'engine-location',
#  'wheel-base',
#  'length',
#  'width',
#  'height',
#  'curb-weight',
#  'engine-type',
#  'num-of-cylinders',
#  'engine-size',
#  'fuel-system',
#  'bore',
#  'stroke',
#  'compression-ratio',
#  'horsepower',
#  'peak-rpm',
#  'city-mpg',
#  'highway-mpg',
#  'price']

# %%
# Usando um arquivo com um nome de coluna por linha
colunas_arq = list(pd.read_csv('/content/drive/MyDrive/Aula 2/colunas', header=None)[0])
colunas_arq
# Out:
# ['symboling',
#  'normalized-losses',
#  'make',
#  'fuel-type',
#  'aspiration',
#  'num-of-doors',
#  'body-style',
#  'drive-wheels',
#  'engine-location',
#  'wheel-base',
#  'length',
#  'width',
#  'height',
#  'curb-weight',
#  'engine-type',
#  'num-of-cylinders',
#  'engine-size',
#  'fuel-system',
#  'bore',
#  'stroke',
#  'compression-ratio',
#  'horsepower',
#  'peak-rpm',
#  'city-mpg',
#  'highway-mpg',
#  'price']

# %%
# Carregar o dataset com as colunas definidas
# Os arquivos .data sao um csv, os arquivos .name aom um .txt
df = pd.read_csv('/content/drive/MyDrive/Aula 2/automobile/imports-85.data', header=None)
df.columns = colunas
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
# Mostrar informações sobre o dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
# Gerar resumo estatístico do dataframe
print(df.describe())
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %%
'''No arquivo da base de dados Automobile, há uma descrição detalhada das informações armazenadas. Neste arquivo, podemos identificar as colunas que possuem valores faltantes.
Com base nessas colunas, faremos a substituição dos valores ausentes,
representados por "?", por "None".'''
# Out:
# 'No arquivo da base de dados Automobile, há uma descrição detalhada das informações armazenadas. Neste arquivo, podemos identificar as colunas que possuem valores faltantes.\nCom base nessas colunas, faremos a substituição dos valores ausentes,\nrepresentados por "?", por "None".'

# %%
# **1. Substituindo "?" por "None" nas colunas com valores faltantes**
# Identificando as colunas que possuem valores faltantes em uma lista

columns_with_missing_values = ['normalized-losses', 'bore', 'stroke', 'horsepower', 'peak-rpm', 'price']
print(df)

# Substituindo "?" por "None" nas colunas identificadas
for column in columns_with_missing_values:
  df[column] = df[column].replace('?', None)

# Visualizando a mudança
print(df) #" Ver DataFrame após a substituição de '?' por 'None':")
print(df.head()) # Imprime as primeiras linhas para verificar
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
# Substituindo "?" por "NaN" nas colunas numéricas e convertendo para float**
# Identificando as colunas numéricas com valores faltantes
numeric_columns_with_missing_values = ['normalized-losses', 'bore', 'stroke', 'horsepower', 'peak-rpm', 'price']

# Convertendo as colunas numéricas para float e substituindo "?" por None
for column in numeric_columns_with_missing_values:
  df[column] = pd.to_numeric(df[column], errors='coerce')

print(df) #Imprime dataframe
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3                NaN  alfa-romero       gas        std
# 1            3                NaN  alfa-romero       gas        std
# 2            1                NaN  alfa-romero       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              164.0         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 200         -1               95.0        volvo       gas        std
# 201         -1               95.0        volvo       gas      turbo
# 202         -1               95.0        volvo       gas        std
# 203         -1               95.0        volvo    diesel      turbo
# 204         -1               95.0        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
# Limpando os valores faltantes da base de dados**
# Verificando a quantidade de valores faltantes em cada coluna
df.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          0
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
 # Usando describe para substituir os valores faltantes pela média**
describe = df.describe()

print(describe)
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  205.000000         164.000000  205.000000  205.000000  205.000000
# mean     0.834146         122.000000   98.756585  174.049268   65.907805
# std      1.245307          35.442168    6.021776   12.337289    2.145204
# min     -2.000000          65.000000   86.600000  141.100000   60.300000
# 25%      0.000000          94.000000   94.500000  166.300000   64.100000
# 50%      1.000000         115.000000   97.000000  173.200000   65.500000
# 75%      2.000000         150.000000  102.400000  183.100000   66.900000
# max      3.000000         256.000000  120.900000  208.100000   72.300000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  205.000000   205.000000   205.000000  201.000000  201.000000
# mean    53.724878  2555.565854   126.907317    3.329751    3.255423
# std      2.443522   520.680204    41.642693    0.273539    0.316717
# ...

# %%
# **6. Substituindo os valores faltantes pela média de cada coluna**
for column in numeric_columns_with_missing_values:
  df[column] = df[column].fillna(describe.loc['mean', column])

print(df)
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3              122.0  alfa-romero       gas        std
# 1            3              122.0  alfa-romero       gas        std
# 2            1              122.0  alfa-romero       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              164.0         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 200         -1               95.0        volvo       gas        std
# 201         -1               95.0        volvo       gas      turbo
# 202         -1               95.0        volvo       gas        std
# 203         -1               95.0        volvo    diesel      turbo
# 204         -1               95.0        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# ...

# %%
# 1. Gráfico de Dispersão (Scatterplot) DarkMode
plt.figure(figsize=(15, 5.5))
plt.style.use('dark_background')  # Define o modo escuro
sns.scatterplot(data=df, x="horsepower", y="price", hue="fuel-type", palette="magma", marker="o", s=50, alpha=0.8)
plt.gca().spines["top"].set_visible(False)
plt.gca().spines["right"].set_visible(False)
plt.gca().spines["left"].set_visible(False)
plt.ylabel("Price (Preço)")
plt.yticks(rotation=45)
plt.xlabel("Horsepower (Cavalos de Potência)")
plt.xticks(range(50, 301, 25))
plt.grid(axis="y", alpha=0.5)
plt.title("Relação entre Preço e Potência do Motor (com Tipo de Combustível)")
plt.legend(title='Fuel Type', loc='upper left')
plt.show()

# %%
# 2. Boxplot Darkmode
plt.figure(figsize=(7, 6))
sns.boxplot(data=df, x="fuel-type", y="price", palette="coolwarm", showmeans=True, meanprops={"marker": "o", "markeredgecolor": "black", "markersize": 8})
plt.ylabel("Price (Preço)")
plt.yticks(rotation=45)
plt.xlabel("Fuel Type (Tipo de Combustível)")
plt.title("Comparação de Preço por Tipo de Combustível")
plt.show()
# Out:
# <ipython-input-141-c874c883b1fc>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="fuel-type", y="price", palette="coolwarm", showmeans=True, meanprops={"marker": "o", "markeredgecolor": "black", "markersize": 8})

# %%
# 3. Histograma Darkmode
sns.displot(data=df, x="engine-size", height=6, aspect=2, kde=True, color="cyan", rug=True)
plt.title("Distribuição do Tamanho do Motor")
plt.xlabel("Engine Size (Tamanho do Motor)")
plt.ylabel("Frequência")
plt.show()

# %%
'''Explicações:

1. Substituindo "?" por "None":
O código identifica as colunas com valores faltantes (columns_with_missing_values).
Um loop itera por essas colunas e substitui '?' por None usando o método replace().
2. Separando as colunas com valores faltantes:
Essa etapa já é realizada dentro do loop da etapa 1.
3. Substituindo "?" por "NaN" e convertendo para float:
O código identifica as colunas numéricas com valores faltantes (numeric_columns_with_missing_values).
Um loop itera por essas colunas:
Utiliza pd.to_numeric(df[column], errors='coerce') para converter a coluna para float e substituir '?' por NaN (valores ausentes).
4. Limpando os valores faltantes:
O código usa df.isnull().sum() para verificar a quantidade de valores faltantes em cada coluna.
5. Usando describe para substituir valores faltantes:
O código utiliza describe = df.describe() para obter as estatísticas descritivas do dataframe.
6. Substituindo valores faltantes pela média:
Um loop itera pelas colunas numéricas com valores faltantes:
Utiliza fillna() para preencher os valores faltantes com a média da coluna, obtida de describe.
7. Gráficos DarkMode Aprimorados:
plt.style.use('dark_background'): Define o modo escuro para o matplotlib.
Paletas de cores: Paletas de cores apropriadas para dark mode (magma, coolwarm, cyan).
Legendas: Adiciona uma legenda ao scatterplot usando plt.legend().
Rótulos de eixo: Os rótulos do eixo y são rotacionados em 45 graus usando plt.yticks(rotation=45).
Títulos mais descritivos: Os títulos dos gráficos foram aprimorados para serem mais específicos sobre o que cada gráfico representa.'''
# Out:
# 'Explicações:\n\n1. Substituindo "?" por "None":\nO código identifica as colunas com valores faltantes (columns_with_missing_values).\nUm loop itera por essas colunas e substitui \'?\' por None usando o método replace().\n2. Separando as colunas com valores faltantes:\nEssa etapa já é realizada dentro do loop da etapa 1.\n3. Substituindo "?" por "NaN" e convertendo para float:\nO código identifica as colunas numéricas com valores faltantes (numeric_columns_with_missing_values).\nUm loop itera por essas colunas:\nUtiliza pd.to_numeric(df[column], errors=\'coerce\') para converter a coluna para float e substituir \'?\' por NaN (valores ausentes).\n4. Limpando os valores faltantes:\nO código usa df.isnull().sum() para verificar a quantidade de valores faltantes em cada coluna.\n5. Usando describe para substituir valores faltantes:\nO código utiliza describe = df.describe() para obter as estatísticas descritivas do dataframe.\n6. Substituindo valores faltantes pela média:\nUm loop itera 
# ...
